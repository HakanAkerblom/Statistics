# %%
import pandas as pd
import seaborn as sns
import scipy.stats
import numpy as np


x_values = [1, 2, 3, 4, 5, 6]
y_values = [1.9, 2.2, 2.2, 2.5, 2.7, 2.6]

x_mean = np.mean(x_values)
y_mean = np.mean(y_values)
sns.lineplot(x =x_values, y= y_values)
y_mean

scipy.stats.pearsonr(x_values, y_values)
scipy.stats.linregress(x_values, y_values)
# Out:
# LinregressResult(slope=0.15142857142857144, intercept=1.82, rvalue=0.9391201333182926, pvalue=0.0054467159552273395, stderr=0.027701027756664744, intercept_stderr=0.10788000388438648)

# %%
from scipy import stats


res = stats.norm.cdf(x=75, loc=67, scale=36)
res
# Out:
# 0.5879295521290574

# %%
res = stats.poisson.cdf(k=30, mu=32)
res
# Out:
# 0.4061480181077554
